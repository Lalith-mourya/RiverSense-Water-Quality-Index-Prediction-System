# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings(action='ignore')

# %%
df=pd.read_csv('water_dataX(4).csv')
df.head()
# Out:
#   STATION CODE                                          LOCATIONS  \
# 0         1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1         1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2         1475                                ZUARI AT PANCHAWADI
# 3         3181                        RIVER ZUARI AT BORIM BRIDGE
# 4         3182                       RIVER ZUARI AT MARCAIM JETTY
#
#          STATE  Temp D.O. (mg/l)   PH CONDUCTIVITY (umhos/cm) B.O.D. (mg/l)  \
# 0  DAMAN & DIU  30.6         6.7  7.5                     203           NAN
# 1          GOA  29.8         5.7  7.2                     189             2
# 2          GOA  29.5         6.3  6.9                     179           1.7
# 3          GOA  29.7         5.8  6.9                      64           3.8
# 4          GOA  29.5         5.8  7.3                      83           1.9
#
#   NITRATENAN N+ NITRITENANN (mg/l) FECAL COLIFORM (MPN/100ml)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1991 entries, 0 to 1990
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   STATION CODE                      1991 non-null   object
#  1   LOCATIONS                         1991 non-null   object
#  2   STATE                             1991 non-null   object
#  3   Temp                              1991 non-null   object
#  4   D.O. (mg/l)                       1991 non-null   object
#  5   PH                                1991 non-null   object
#  6   CONDUCTIVITY (umhos/cm)           1991 non-null   object
#  7   B.O.D. (mg/l)                     1991 non-null   object
#  8   NITRATENAN N+ NITRITENANN (mg/l)  1991 non-null   object
#  9   FECAL COLIFORM (MPN/100ml)        1991 non-null   object
#  10  TOTAL COLIFORM (MPN/100ml)Mean    1991 non-null   object
# ...

# %%
df.head(2)
# Out:
#   STATION CODE                                          LOCATIONS  \
# 0         1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1         1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
#
#          STATE  Temp D.O. (mg/l)   PH CONDUCTIVITY (umhos/cm) B.O.D. (mg/l)  \
# 0  DAMAN & DIU  30.6         6.7  7.5                     203           NAN
# 1          GOA  29.8         5.7  7.2                     189             2
#
#   NITRATENAN N+ NITRITENANN (mg/l) FECAL COLIFORM (MPN/100ml)  \
# 0                              0.1                         11
# 1                              0.2                       4953
#
#   TOTAL COLIFORM (MPN/100ml)Mean  year
# 0                             27  2014
# 1                           8391  2014

# %%
df.columns
# Out:
# Index(['STATION CODE', 'LOCATIONS', 'STATE', 'Temp', 'D.O. (mg/l)', 'PH',
#        'CONDUCTIVITY (umhos/cm)', 'B.O.D. (mg/l)',
#        'NITRATENAN N+ NITRITENANN (mg/l)', 'FECAL COLIFORM (MPN/100ml)',
#        'TOTAL COLIFORM (MPN/100ml)Mean', 'year'],
#       dtype='object')

# %%
df.describe()
# Out:
#               year
# count  1991.000000
# mean   2010.038172
# std       3.057333
# min    2003.000000
# 25%    2008.000000
# 50%    2011.000000
# 75%    2013.000000
# max    2014.000000

# %%
df.isnull().sum()
# Out:
# STATION CODE                        0
# LOCATIONS                           0
# STATE                               0
# Temp                                0
# D.O. (mg/l)                         0
# PH                                  0
# CONDUCTIVITY (umhos/cm)             0
# B.O.D. (mg/l)                       0
# NITRATENAN N+ NITRITENANN (mg/l)    0
# FECAL COLIFORM (MPN/100ml)          0
# TOTAL COLIFORM (MPN/100ml)Mean      0
# year                                0
# dtype: int64

# %%
cols = ['Temp', 'D.O. (mg/l)', 'PH', 'CONDUCTIVITY (umhos/cm)', 'B.O.D. (mg/l)',
        'NITRATENAN N+ NITRITENANN (mg/l)', 'FECAL COLIFORM (MPN/100ml)', 'TOTAL COLIFORM (MPN/100ml)Mean']

for col in cols:
    df[col] = df[col].replace(r'^\s*$', 'NAN', regex=True)

# %%
df.drop(['year'],axis=1,inplace=True)

# %%
df.replace('NAN', 0, inplace=True)
df[df['Temp']=='NAN']
# Out:
# Empty DataFrame
# Columns: [STATION CODE, LOCATIONS, STATE, Temp, D.O. (mg/l), PH, CONDUCTIVITY (umhos/cm), B.O.D. (mg/l), NITRATENAN N+ NITRITENANN (mg/l), FECAL COLIFORM (MPN/100ml), TOTAL COLIFORM (MPN/100ml)Mean]
# Index: []

# %%
df['Temp']=df['Temp'].astype(float)

# %%
df.columns
# Out:
# Index(['STATION CODE', 'LOCATIONS', 'STATE', 'Temp', 'D.O. (mg/l)', 'PH',
#        'CONDUCTIVITY (umhos/cm)', 'B.O.D. (mg/l)',
#        'NITRATENAN N+ NITRITENANN (mg/l)', 'FECAL COLIFORM (MPN/100ml)',
#        'TOTAL COLIFORM (MPN/100ml)Mean'],
#       dtype='object')

# %%
median_temp = df['Temp'].median()
df['Temp'].replace(0,median_temp, inplace=True)

# %%
median_temp = df['D.O. (mg/l)'].median()
df['D.O. (mg/l)'].replace(0,median_temp, inplace=True)

# %%
df['D.O. (mg/l)'] = pd.to_numeric(df['D.O. (mg/l)'], errors='coerce')

# Compute median ignoring NaNs
median_do = df['D.O. (mg/l)'].median()

# Replace 0 with median
df.loc[df['D.O. (mg/l)'] == 0, 'D.O. (mg/l)'] = median_do

# %%
median_temp = df['PH'].median()
df['PH'].replace(0,median_temp, inplace=True)

# %%
median_temp = df['CONDUCTIVITY (umhos/cm)'].median()
df['CONDUCTIVITY (umhos/cm)'].replace(0,median_temp, inplace=True)

# %%
median_temp = df['B.O.D. (mg/l)'].median()
df['B.O.D. (mg/l)'].replace(0,median_temp, inplace=True)

# %%
median_temp = df['NITRATENAN N+ NITRITENANN (mg/l)'].median()
df['NITRATENAN N+ NITRITENANN (mg/l)'].replace(0,median_temp, inplace=True)

# %%
median_temp = df['FECAL COLIFORM (MPN/100ml)'].median()
df['FECAL COLIFORM (MPN/100ml)'].replace(0,median_temp, inplace=True)

# %%
median_temp = df['TOTAL COLIFORM (MPN/100ml)Mean'].median()
df['TOTAL COLIFORM (MPN/100ml)Mean'].replace(0,median_temp, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1991 entries, 0 to 1990
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   STATION CODE                      1991 non-null   object
#  1   LOCATIONS                         1991 non-null   object
#  2   STATE                             1991 non-null   object
#  3   Temp                              1991 non-null   float64
#  4   D.O. (mg/l)                       1991 non-null   float64
#  5   PH                                1991 non-null   object
#  6   CONDUCTIVITY (umhos/cm)           1991 non-null   object
#  7   B.O.D. (mg/l)                     1991 non-null   object
#  8   NITRATENAN N+ NITRITENANN (mg/l)  1991 non-null   object
#  9   FECAL COLIFORM (MPN/100ml)        1991 non-null   object
#  10  TOTAL COLIFORM (MPN/100ml)Mean    1991 non-null   object
# dtypes: float64(2), object(9)
# ...

# %%
Columns = ['D.O. (mg/l)','PH','CONDUCTIVITY (umhos/cm)','B.O.D. (mg/l)',
           'NITRATENAN N+ NITRITENANN (mg/l)','FECAL COLIFORM (MPN/100ml)', 
           'TOTAL COLIFORM (MPN/100ml)Mean']
df[Columns] = df[Columns].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1991 entries, 0 to 1990
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   STATION CODE                      1991 non-null   object
#  1   LOCATIONS                         1991 non-null   object
#  2   STATE                             1991 non-null   object
#  3   Temp                              1991 non-null   float64
#  4   D.O. (mg/l)                       1991 non-null   float64
#  5   PH                                1991 non-null   float64
#  6   CONDUCTIVITY (umhos/cm)           1991 non-null   float64
#  7   B.O.D. (mg/l)                     1991 non-null   float64
#  8   NITRATENAN N+ NITRITENANN (mg/l)  1991 non-null   float64
#  9   FECAL COLIFORM (MPN/100ml)        1991 non-null   float64
#  10  TOTAL COLIFORM (MPN/100ml)Mean    1991 non-null   float64
# dtypes: float64(8), object(3)
# ...

# %%
df.head(2)
# Out:
#   STATION CODE                                          LOCATIONS  \
# 0         1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1         1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
#
#          STATE  Temp  D.O. (mg/l)   PH  CONDUCTIVITY (umhos/cm)  \
# 0  DAMAN & DIU  30.6          6.7  7.5                    203.0
# 1          GOA  29.8          5.7  7.2                    189.0
#
#    B.O.D. (mg/l)  NITRATENAN N+ NITRITENANN (mg/l)  \
# 0            1.8                               0.1
# 1            2.0                               0.2
#
#    FECAL COLIFORM (MPN/100ml)  TOTAL COLIFORM (MPN/100ml)Mean
# 0                        11.0                            27.0
# 1                      4953.0                          8391.0

# %%
df.drop(['STATION CODE','LOCATIONS'],axis=1,inplace=True)

# %%
df.head()
# Out:
#          STATE  Temp  D.O. (mg/l)   PH  CONDUCTIVITY (umhos/cm)  \
# 0  DAMAN & DIU  30.6          6.7  7.5                    203.0
# 1          GOA  29.8          5.7  7.2                    189.0
# 2          GOA  29.5          6.3  6.9                    179.0
# 3          GOA  29.7          5.8  6.9                     64.0
# 4          GOA  29.5          5.8  7.3                     83.0
#
#    B.O.D. (mg/l)  NITRATENAN N+ NITRITENANN (mg/l)  \
# 0            1.8                               0.1
# 1            2.0                               0.2
# 2            1.7                               0.1
# 3            3.8                               0.5
# 4            1.9                               0.4
#
#    FECAL COLIFORM (MPN/100ml)  TOTAL COLIFORM (MPN/100ml)Mean
# 0                        11.0                            27.0
# 1                      4953.0                          8391.0
# 2                      3243.0                          5330.0
# ...

# %%
df['STATE'].value_counts()
# Out:
# STATE
# 0                                                   761
# KERALA                                              275
# MAHARASHTRA                                         142
# MEGHALAYA                                           125
# GOA                                                 101
#                                                    ...
# GUMTI AT D/S SOUTH TRIPURA, TRIPURA                   1
# CHANDRAPUR, AGARTALA D/S OF HAORA RIVER, TRIPURA      1
# MYNTDU JAINTIA HILLS MEGHALAYA                        1
# SIMSANG, WILLIAMNAGAR, MEGHALAYA                      1
# GANOL, TURA, MEGHALAYA                                1
# Name: count, Length: 203, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparse_output=False)

# %%
df.columns
# Out:
# Index(['STATE', 'Temp', 'D.O. (mg/l)', 'PH', 'CONDUCTIVITY (umhos/cm)',
#        'B.O.D. (mg/l)', 'NITRATENAN N+ NITRITENANN (mg/l)',
#        'FECAL COLIFORM (MPN/100ml)', 'TOTAL COLIFORM (MPN/100ml)Mean'],
#       dtype='object')

# %%
df['STATE'] = df['STATE'].astype(str)

# %%
df.rename(columns={
    'D.O. (mg/l)': 'do',
    'PH': 'ph',
    'CONDUCTIVITY (umhos/cm)': 'co',
    'B.O.D. (mg/l)': 'bod',
    'NITRATENAN N+ NITRITENANN (mg/l)': 'na',
    'FECAL COLIFORM (MPN/100ml)': 'fc',
    'TOTAL COLIFORM (MPN/100ml)Mean': 'tc'
}, inplace=True)

# %%
df.head(2)
# Out:
#          STATE  Temp   do   ph     co  bod   na      fc      tc
# 0  DAMAN & DIU  30.6  6.7  7.5  203.0  1.8  0.1    11.0    27.0
# 1          GOA  29.8  5.7  7.2  189.0  2.0  0.2  4953.0  8391.0

# %%
df['npH'] = df.ph.apply(lambda x: (100 if (8.5 >= x >= 7)
                                       else (80 if (8.6 >= x >= 8.5) or (6.9 >= x >= 6.8)
                                             else (60 if (8.8 >= x >= 8.6) or (6.8 >= x >= 6.7)
                                                   else (40 if (9 >= x >= 8.8) or (6.7 >= x >= 6.5)
                                                         else 0)))))

# %%
# calculation of dissolved oxygen
df['ndo'] = df.do.apply(lambda x: (100 if (x >= 6)
                                       else (80 if (6 >= x >= 5.1)
                                             else (60 if (5 >= x >= 4.1)
                                                   else (40 if (4 >= x >= 3)
                                                         else 0)))))

# %%
# calculation of total coliform
df['nco'] = df.tc.apply(lambda x: (100 if (5 >= x >= 0)
                                       else (80 if (50 >= x >= 5)
                                             else (60 if (500 >= x >= 50)
                                                   else (40 if (10000 >= x >= 500)
                                                         else 0)))))

# %%
# calc of B.D.O
df['nbdo'] = df.bod.apply(lambda x: (100 if (3 >= x >= 0)
                                         else (80 if (6 >= x >= 3)
                                               else (60 if (80 >= x >= 6)
                                                     else (40 if (125 >= x >= 80)
                                                           else 0)))))

# %%
# calculation of electrical conductivity
df['nec'] = df.co.apply(lambda x: (100 if (75 >= x >= 0)
                                       else (80 if (150 >= x >= 75)
                                             else (60 if (225 >= x >= 150)
                                                   else (40 if (300 >= x >= 225)
                                                         else 0)))))

# %%
# Calulation of nitrate
df['nna'] = df.na.apply(lambda x: (100 if (20 >= x >= 0)
                                       else (80 if (50 >= x >= 20)
                                             else (60 if (100 >= x >= 50)
                                                   else (40 if (200 >= x >= 100)
                                                         else 0)))))  else (80 if (8.6 >= x >= 8.5) or (6.9 >= x >= 6.8)
                                             else (60 if (8.8 >= x >= 8.6) or (6.8 >= x >= 6.7)
                                                   else (40 if (9 >= x >= 8.8) or (6.7 >= x >= 6.5)
                                                         else 0)))))

# %%
# calculation of dissolved oxygen
df['ndo'] = df.do.apply(lambda x: (100 if (x >= 6)
                                       else (80 if (6 >= x >= 5.1)
                                             else (60 if (5 >= x >= 4.1)
                                                   else (40 if (4 >= x >= 3)
                                                         else 0)))))

# %%
# calculation of total coliform
df['nco'] = df.tc.apply(lambda x: (100 if (5 >= x >= 0)
                                       else (80 if (50 >= x >= 5)
                                             else (60 if (500 >= x >= 50)
                                                   else (40 if (10000 >= x >= 500)
                                                         else 0)))))

# %%
# calc of B.D.O
df['nbdo'] = df.bod.apply(lambda x: (100 if (3 >= x >= 0)
                                         else (80 if (6 >= x >= 3)
                                               else (60 if (80 >= x >= 6)
                                                     else (40 if (125 >= x >= 80)
                                                           else 0)))))

# %%
# calculation of electrical conductivity
df['nec'] = df.co.apply(lambda x: (100 if (75 >= x >= 0)
                                       else (80 if (150 >= x >= 75)
                                             else (60 if (225 >= x >= 150)
                                                   else (40 if (300 >= x >= 225)
                                                         else 0)))))

# %%
# Calulation of nitrate
df['nna'] = df.na.apply(lambda x: (100 if (20 >= x >= 0)
                                       else (80 if (50 >= x >= 20)
                                             else (60 if (100 >= x >= 50)
                                                   else (40 if (200 >= x >= 100)
                                                         else 0)))))

df.head()
df.dtypes
# Out:
#   Cell In[165], line 48
#     else 0)))))
#              ^
# SyntaxError: unmatched ')'
